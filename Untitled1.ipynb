# %%
import pandas as pd

# %%
data = {
    "id": [1, 2, 3, 4, 5],
    "product customer purchased": ["Widget A", "Widget B", "Widget A", "Widget C", "Widget B"],
    "Name of customer": ["John Doe", "Jane Smith", "Bob Johnson", "Susan Brown", "Mary Wilson"],
    "address of customer": ["123 Main St", "456 Elm St", "789 Oak St", "234 Pine St", "567 Birch St"],
    "email of customer": ["john.doe@email.com", "", "bob.johnson@email.com", "susan.brown@email.com", "mary.wilson@email.com"],
    "phone number of customer": ["123-456-7890", "987-654-3210", "555-123-7890", "777-888-9999", "111-222-3333"],
    "time of purchase": ["2023-08-10 09:15:00", "2023-08-10 10:30:00", "2023-08-11 14:45:00", "2023-08-11 15:30:00", "2023-08-12 11:20:00"]
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    id product customer purchased Name of customer address of customer  \
# 0   1                   Widget A         John Doe         123 Main St
# 1   2                   Widget B       Jane Smith          456 Elm St
# 2   3                   Widget A      Bob Johnson          789 Oak St
# 3   4                   Widget C      Susan Brown         234 Pine St
# 4   5                   Widget B      Mary Wilson        567 Birch St
#
#        email of customer phone number of customer     time of purchase
# 0     john.doe@email.com             123-456-7890  2023-08-10 09:15:00
# 1                                    987-654-3210  2023-08-10 10:30:00
# 2  bob.johnson@email.com             555-123-7890  2023-08-11 14:45:00
# 3  susan.brown@email.com             777-888-9999  2023-08-11 15:30:00
# 4  mary.wilson@email.com             111-222-3333  2023-08-12 11:20:00

# %%
df.tail()
# Out:
#    id product customer purchased Name of customer address of customer  \
# 0   1                   Widget A         John Doe         123 Main St
# 1   2                   Widget B       Jane Smith          456 Elm St
# 2   3                   Widget A      Bob Johnson          789 Oak St
# 3   4                   Widget C      Susan Brown         234 Pine St
# 4   5                   Widget B      Mary Wilson        567 Birch St
#
#        email of customer phone number of customer     time of purchase
# 0     john.doe@email.com             123-456-7890  2023-08-10 09:15:00
# 1                                    987-654-3210  2023-08-10 10:30:00
# 2  bob.johnson@email.com             555-123-7890  2023-08-11 14:45:00
# 3  susan.brown@email.com             777-888-9999  2023-08-11 15:30:00
# 4  mary.wilson@email.com             111-222-3333  2023-08-12 11:20:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          5 non-null      int64
#  1   product customer purchased  5 non-null      object
#  2   Name of customer            5 non-null      object
#  3   address of customer         5 non-null      object
#  4   email of customer           5 non-null      object
#  5   phone number of customer    5 non-null      object
#  6   time of purchase            5 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 412.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# Exercise
df_1 = pd.read_csv("Exercise Files/Chapter_1/sample_data.csv")

# %%
df_1
# Out:
#                   Name                        Email                 Phone  \
# 0            Lisa West         andrew23@example.com         (465)852-8470
# 1           Jason Cole        kenneth05@example.net            7783540568
# 2          Juan Crosby          zbarnes@example.org   (676)328-6244x05295
# 3           April Ball  michaelmckinney@example.com  +1-633-685-4901x2113
# 4       Donald Jackson        peterdean@example.com          779-437-7643
# ..                 ...                          ...                   ...
# 195     Willie Shelton       jamesdavis@example.net      277-426-9077x821
# 196  Deborah Nicholson       michelle15@example.net     954-765-9968x1900
# 197         Vanessa Wu    reginaldowens@example.com  +1-682-798-1566x9050
# 198        Robyn Allen           chad33@example.org      212-239-3934x599
# 199      Scott Stewart        valerie39@example.com          956.897.0540
#
#                                                Address           City  \
# ...

# %%
df_1.shape
# Out:
# (200, 8)

# %%
df_1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195     True
# 196     True
# 197     True
# 198     True
# 199     True
# Length: 200, dtype: bool

# %% [markdown]
# LOADING WITH PANDAS

# %%
sample_csv = pd.read_csv("Exercise Files/Chapter_2/sample_data_csv.csv", header = None)

# %%
sample_csv.head()
# Out:
#                 0                            1                     2  \
# 0       Lisa West         andrew23@example.com         (465)852-8470
# 1      Jason Cole        kenneth05@example.net            7783540568
# 2     Juan Crosby          zbarnes@example.org   (676)328-6244x05295
# 3      April Ball  michaelmckinney@example.com  +1-633-685-4901x2113
# 4  Donald Jackson        peterdean@example.com          779-437-7643
#
#                                                    3              4  \
# 0                 Unit 5183 Box 8914\r\nDPO AP 26775      Perezfort
# 1  73784 Kenneth Stream Apt. 200\r\nFitzgeraldshi...    Port Andrea
# 2        0580 Mary Row\r\nLake Vanessabury, GA 81529    Johnborough
# 3  6215 Hensley Pass Apt. 136\r\nSouth Patricia, ...       New Eric
# 4   156 Macdonald Alley\r\nWest Scottmouth, MA 82872  Alyssaborough
#
#               5           6        7
# 0      Honduras  2001-08-05  83302.0
# 1       Bolivia  2012-12-04  31035.0
# ...

# %%
customers = pd.read_excel("Exercise Files/Chapter_2/H+ Sport Customers.xlsx", sheet_name="data")

# %%
customers.shape
# Out:
# (1029, 9)

# %%
customers.columns
# Out:
# Index(['CustomerID', 'FirstName', 'LastName', 'Email', 'Phone', 'Address',
#        'City', 'State', 'Zipcode'],
#       dtype='object')

# %%
columns_to_check = ['Email', 'Phone', 'FirstName', 'LastName']

# %%
duplicates = customers[customers.duplicated(columns_to_check)]

# %%
duplicates
# Out:
#       CustomerID FirstName  LastName                          Email  \
# 1000        1100     Chris    Moreno              cmorenond@mac.com
# 1001        1101    Gerald     Green              ggreenne@wisc.edu
# 1002        1102    Johnny      Ruiz                jruiznf@nba.com
# 1003        1103    Carlos   Morales              cmoralesng@ed.gov
# 1004        1104    Gloria     Ramos              gramosnh@xing.com
# 1005        1105  Lawrence   Sanchez           lsanchezni@prlog.org
# 1006        1106    Philip     Hayes             phayesnj@adobe.com
# 1007        1107    George     Ortiz           gortiznk@dropbox.com
# 1008        1108      Lois   Andrews     landrewsnl@tripadvisor.com
# 1009        1109   Russell    Lawson             rlawsonnm@ebay.com
# 1010        1110   Richard    George             rgeorgenn@usda.gov
# 1011        1111    Cheryl     Moore  cmooreno@networksolutions.com
# 1012        1112     Sarah      Sims              ssimsnp@issuu.com
# ...

# %%
duplicates.shape
# Out:
# (29, 9)

# %%
customers = customers[customers.duplicated(columns_to_check, keep='first')]

# %%
customers
# Out:
#       CustomerID FirstName LastName                          Email  \
# 1015        1115     Chris   Moreno              cmorenond@mac.com
# 1016        1116    Gerald    Green              ggreenne@wisc.edu
# 1017        1117    Johnny     Ruiz                jruiznf@nba.com
# 1018        1118    Carlos  Morales              cmoralesng@ed.gov
# 1019        1119    Gloria    Ramos              gramosnh@xing.com
# 1020        1120  Lawrence  Sanchez           lsanchezni@prlog.org
# 1021        1121    Philip    Hayes             phayesnj@adobe.com
# 1022        1122    George    Ortiz           gortiznk@dropbox.com
# 1023        1123      Lois  Andrews     landrewsnl@tripadvisor.com
# 1024        1124   Russell   Lawson             rlawsonnm@ebay.com
# 1025        1125   Richard   George             rgeorgenn@usda.gov
# 1026        1126    Cheryl    Moore  cmooreno@networksolutions.com
# 1027        1127     Sarah     Sims              ssimsnp@issuu.com
# ...

# %%
customers.isnull().sum()
# Out:
# CustomerID    0
# FirstName     0
# LastName      0
# Email         0
# Phone         0
# Address       0
# City          0
# State         0
# Zipcode       0
# dtype: int64

# %% [markdown]
# CHALLENGE 2

# %%
data_emp = pd.read_excel("Exercise Files/Chapter_2/H+ Sport Employees.xlsx", sheet_name = "Employees")

# %%
data_emp.head()
# Out:
#       Employee Name Building Department     Status  Hire Date Month  Years  \
# 0        Page, Lisa     West        ADC  Full Time 1999-01-11   Jan     25
# 1    Taylor, Hector     West        ADC  Half-Time 2011-02-21   Feb     12
# 2  Dawson, Jonathan     West        ADC   Contract 2007-03-06   Mar     16
# 3      Duran, Brian     Taft        ADC     Hourly 2012-08-30   Aug     11
# 4      Weber, Larry   Watson        ADC  Full Time 2007-12-31   Dec     16
#
#   Benefits  Salary  Job Rating  New Salary  Tax Rate  0.0291
# 0      DMR   24550           1         NaN       NaN     NaN
# 1       DM   26795           4         NaN       NaN     NaN
# 2      NaN   42540           5         NaN       NaN     NaN
# 3      NaN   35680           2         NaN       NaN     NaN
# 4        M   72830           2         NaN       NaN     NaN

# %%
data_emp.columns
# Out:
# Index(['Employee Name',      'Building',    'Department',        'Status',
#            'Hire Date',         'Month',         'Years',      'Benefits',
#               'Salary',    'Job Rating',    'New Salary',      'Tax Rate',
#                 0.0291],
#       dtype='object')

# %%
columns_to_remove = ['Job Rating',    'New Salary',      'Tax Rate',
                0.0291]

# %%
data_emp = data_emp.drop(columns = columns_to_remove)

# %%
data_emp
# Out:
#         Employee Name Building            Department     Status  Hire Date  \
# 0          Page, Lisa     West                   ADC  Full Time 1999-01-11
# 1      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 2    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 3        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 4        Weber, Larry   Watson                   ADC  Full Time 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 736       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 737        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 738  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 739      Riley, David     Taft  Research/Development  Full Time 2010-07-25
# 740    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
#     Month  Years Benefits  Salary
# ...

# %%
data_emp.columns
# Out:
# Index(['Employee Name', 'Building', 'Department', 'Status', 'Hire Date',
#        'Month', 'Years', 'Benefits', 'Salary'],
#       dtype='object')

# %% [markdown]
# DATA WAREHOUSE

# %%
pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 388.9 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/2.1 MB 573.4 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.1 MB 581.0 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.1 MB 697.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/2.1 MB 860.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.1 MB 785.2 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 863.3 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/2.1 MB 776.5 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 1.0 MB/s eta 0:00:02
# ...

# %%
import sqlalchemy as db

# %%
customers = pd.read_excel('Exercise Files/Chapter_3/H+ Sport Customers.xlsx', sheet_name = "data")

# %%
customers.drop_duplicates()
# Out:
#      CustomerID  FirstName  LastName                       Email  \
# 0           100      Carol      Shaw              cshaw0@mlb.com
# 1           101  Elizabeth      Carr           ecarr1@oracle.com
# 2           102     Ernest     Ramos         eramos2@plala.or.jp
# 3           103       Jane    Carter        jcarter3@harvard.edu
# 4           104     Martha    Cooper             mcooper4@go.com
# ..          ...        ...       ...                         ...
# 995        1095      Helen  Castillo     hcastillorn@behance.net
# 996        1096      Peter  Crawford           pcrawfordro@de.vu
# 997        1097     Samuel    Fields  sfieldsrp@reverbnation.com
# 998        1098    Michael  Gonzalez         mgonzalezrq@hud.gov
# 999        1099     Louise  Morrison       lmorrisonrr@nifty.com
#
#              Phone                 Address         City State  Zipcode
# 0    (206)804-8771     8157 Longview Court      Seattle    WA    98121
# ...

# %%
customers = customers.drop(columns = 'Zipcode')

# %%
customers
# Out:
#      CustomerID  FirstName  LastName                       Email  \
# 0           100      Carol      Shaw              cshaw0@mlb.com
# 1           101  Elizabeth      Carr           ecarr1@oracle.com
# 2           102     Ernest     Ramos         eramos2@plala.or.jp
# 3           103       Jane    Carter        jcarter3@harvard.edu
# 4           104     Martha    Cooper             mcooper4@go.com
# ..          ...        ...       ...                         ...
# 995        1095      Helen  Castillo     hcastillorn@behance.net
# 996        1096      Peter  Crawford           pcrawfordro@de.vu
# 997        1097     Samuel    Fields  sfieldsrp@reverbnation.com
# 998        1098    Michael  Gonzalez         mgonzalezrq@hud.gov
# 999        1099     Louise  Morrison       lmorrisonrr@nifty.com
#
#              Phone                 Address         City State
# 0    (206)804-8771     8157 Longview Court      Seattle    WA
# ...

# %%
engine = db.create_engine('postgresql://xiypbxkx:icSe0mQjmcvzRkjEqm7vwrLr1eTGTQG7@isabelle.db.elephantsql.com/xiypbxkx')

# %%
customers.to_sql("customers", engine, if_exists = 'replace', index = False)
# Out:
# 1000

# %%
customers.shape
# Out:
# (1000, 8)

# %% [markdown]
# CHALLENGE 3

# %%
engine_2 = db.create_engine('postgresql://xiypbxkx:icSe0mQjmcvzRkjEqm7vwrLr1eTGTQG7@isabelle.db.elephantsql.com/xiypbxkx')

# %%
data_emp.to_sql("employees", engine_2, if_exists = 'replace', index = False)
# Out:
# 741

# %%
data_emp.shape
# Out:
# (741, 9)

# %% [markdown]
# INTERROGATION DU DATAWAREHOUSE

# %%
airflow db init
# Out:
#   Cell In[1], line 1
#     airflow db init
#             ^
# SyntaxError: invalid syntax

# %%
import airflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 import airflow
#
# ModuleNotFoundError: No module named 'airflow'

# %%
pip install airflow
# Out:
# ...
#   Using cached airflow-0.6.tar.gz (1.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Error [WinError 225] Impossible de terminer l’opération, car le fichier contient un virus ou un logiciel potentiellement indésirable while executing command python setup.py egg_info
# ERROR: Could not install packages due to an OSError: [WinError 225] Impossible de terminer l’opération, car le fichier contient un virus ou un logiciel potentiellement indésirable
